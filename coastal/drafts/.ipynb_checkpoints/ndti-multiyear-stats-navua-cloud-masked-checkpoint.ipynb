# %% [markdown]
# <img src="https://github.com/nicholasmetherall/digital-earth-pacific-macblue-activities/blob/main/attachments/images/DE_Pacific_banner.JPG?raw=true" width="900"/>
# Figure 1.1.a. Jupyter environment + Python notebooks
#
# ### NDTI analyses
#
# Some inputs from the following notebooks: https://docs.digitalearthafrica.org/en/latest/sandbox/notebooks/Real_world_examples/Wetland_turbidity.html

# %%
from pystac_client import Client
from dask.distributed import Client as DaskClient
from odc.stac import load, configure_s3_access
import rasterio as rio
import geopandas as gpd
import pandas as pd
import numpy as np
import xarray as xr
import folium
import utils
from utils import load_data
# from utils import mask_and_scale
from sklearn.ensemble import RandomForestClassifier
import odc.geo.xr
import rioxarray
import matplotlib.pyplot as plt
from datetime import datetime
from odc.stac import load

# %% [markdown]
# Define catalogue

# %%
catalogue = "https://earth-search.aws.element84.com/v1"
client = Client.open(catalogue)

# %%
# #Navua
# min_lat = -18.277530
# min_lon = 178.144327
# max_lat = -18.252355
# max_lon = 178.171476

# -18.279530, 178.142327
# -18.254355, 178.169476

# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
# # #Suva
# min_lat = -18.215062
# min_lon = 178.403377
# max_lat = -18.086312
# max_lon = 178.604283


# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
# #PNG
# min_lat = -8.8464615
# min_lon = 142.018333
# max_lat = -7.9750438
# max_lon = 143.911034


# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
# #Solomon Islands
# min_lat =  -9.427281
# min_lon =  160.01445
# max_lat = -9.3973759
# max_lon = 160.040215


# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
#PNG 2 bootlessbay
# min_lat = -9.5172643
# min_lon = 147.272733
# max_lat = -9.4927668
# max_lon = 147.292422


# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
# #Ra
# min_lat = -17.515442
# min_lon = 178.188805
# max_lat = -17.367698
# max_lon = 178.327742
 
 
# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
# #Vusasivo
# min_lat = -16.574914
# min_lon = 179.756094
# max_lat = -16.563194
# max_lon = 179.761568
 
 
# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
# #Efate
# min_lon = 168.38677
# min_lat = -17.53851
# max_lon = 168.44753
# max_lat = -17.50726

# bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
#geojson
gdf = gpd.read_file("serua.geojson")
#version = "malekula_joined_model_mask_test3"
#gdf = gpd.read_file("training-data/Alluvium_vu_malekula_13022025.geojson")
gdf = gdf.to_crs("EPSG:4326")
min_lon, min_lat, max_lon, max_lat = gdf.total_bounds
bbox = [min_lon, min_lat, max_lon, max_lat]

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bcb893e84402c5fafc360f93ced5529 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bcb893e84402c5fafc360f93ced5529&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bcb893e84402c5fafc360f93ced5529 = L.map(
#                 &quot;map_1bcb893e84402c5fafc360f93ced5529&quot;,
#                 {
#                     center: [-18.258437930342552, 177.83275000021007],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1bcb893e84402c5fafc360f93ced5529);
#
#
#
#
#
#             var tile_layer_9321665a876c9d51dca28a088741f34c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9321665a876c9d51dca28a088741f34c.addTo(map_1bcb893e84402c5fafc360f93ced5529);
#
#
#             map_1bcb893e84402c5fafc360f93ced5529.fitBounds(
#                 [[-18.262035860685103, 177.82930166666665], [-18.25484, 177.8361983337535]],
#                 {}
#             );
#
#
#         function geo_json_c530d5709f809f0dc38f9524fa9887ec_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c530d5709f809f0dc38f9524fa9887ec_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c530d5709f809f0dc38f9524fa9887ec_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_c530d5709f809f0dc38f9524fa9887ec_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c530d5709f809f0dc38f9524fa9887ec_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_c530d5709f809f0dc38f9524fa9887ec.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c530d5709f809f0dc38f9524fa9887ec_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c530d5709f809f0dc38f9524fa9887ec = L.geoJson(null, {
#                 onEachFeature: geo_json_c530d5709f809f0dc38f9524fa9887ec_onEachFeature,
#
#                 style: geo_json_c530d5709f809f0dc38f9524fa9887ec_styler,
#                 pointToLayer: geo_json_c530d5709f809f0dc38f9524fa9887ec_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_c530d5709f809f0dc38f9524fa9887ec_add (data) {
#             geo_json_c530d5709f809f0dc38f9524fa9887ec
#                 .addData(data);
#         }
#             geo_json_c530d5709f809f0dc38f9524fa9887ec_add({&quot;bbox&quot;: [177.82930166666665, -18.262035860685103, 177.8361983337535, -18.25484], &quot;features&quot;: [{&quot;bbox&quot;: [177.834515, -18.25484, 177.834515, -18.25484], &quot;geometry&quot;: {&quot;coordinates&quot;: [177.834515, -18.25484], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;cc_id&quot;: 3, &quot;date&quot;: &quot;2025-01-26&quot;, &quot;fid&quot;: 1, &quot;obser

# %%
date_start = "2017-01"

# %%
# Get the current date and time
date_end = datetime.now()
# Format as a string (e.g., "2025-06-30")
date_end = date_end.strftime("%Y-%m")
print(date_end)
# Out:
# 2025-07

# %%
datetime = date_start+'/'+date_end
print(datetime)
# Out:
# 2017-01/2025-07

# %% [markdown]
# Connect to parallel computers for greater computational capacity - note you should only run this line of code once per notebook activity - do not rerun this line

# %% [markdown]
# Search through the catalogue - define the cloud cover threshold you want. Try changing 80 to 50 here: `{"lt": 50}},`

# %%
# Search through catalogue for relevant data
items = client.search(
    collections=["sentinel-2-l2a"],
    bbox=bbox,
    datetime=datetime,
    query={"eo:cloud_cover":{"lt": 35}},
).item_collection()

print(f"Found {len(items)} items")
# Out:
# Found 330 items

# %%
selected_item = sorted(items, key=lambda item: item.properties["eo:cloud_cover"])[0]
for asset_key, asset in selected_item.assets.items():
    print(f"{asset_key:<25} - {asset.title}")
# Out:
# aot                       - Aerosol optical thickness (AOT)
# blue                      - Blue (band 2) - 10m
# coastal                   - Coastal aerosol (band 1) - 60m
# granule_metadata          - None
# green                     - Green (band 3) - 10m
# nir                       - NIR 1 (band 8) - 10m
# nir08                     - NIR 2 (band 8A) - 20m
# nir09                     - NIR 3 (band 9) - 60m
# red                       - Red (band 4) - 10m
# rededge1                  - Red edge 1 (band 5) - 20m
# rededge2                  - Red edge 2 (band 6) - 20m
# rededge3                  - Red edge 3 (band 7) - 20m
# scl                       - Scene classification map (SCL)
# swir16                    - SWIR 1 (band 11) - 20m
# swir22                    - SWIR 2 (band 12) - 20m
# thumbnail                 - Thumbnail image
# tileinfo_metadata         - None
# visual                    - True color image
# wvp                       - Water vapour (WVP)
# aot-jp2                   - Aerosol optical thickness (AOT)
# blue-jp2                  - Blue (band 2) - 10m
# coastal-jp2               - Coastal aerosol (band 1) - 60m
# green-jp2                 - Green (band 3) - 10m
# nir-jp2                   - NIR 1 (band 8) - 10m
# nir08-jp2                 - NIR 2 (band 8A) - 20m
# nir09-jp2                 - NIR 3 (band 9) - 60m
# red-jp2                   - Red (band 4) - 10m
# rededge1-jp2              - Red edge 1 (band 5) - 20m
# rededge2-jp2              - Red edge 2 (band 6) - 20m
# rededge3-jp2              - Red edge 3 (band 7) - 20m
# scl-jp2                   - Scene classification map (SCL)
# swir16-jp2                - SWIR 1 (band 11) - 20m
# swir22-jp2                - SWIR 2 (band 12) - 20m
# visual-jp2                - True color image
# wvp-jp2                   - Water vapour (WVP)

# %% [markdown]
# <font color='blue'>Load your satellite dataset based on your search parameters defined above</font>

# %%
data = load(
    items,
    chunks={},
    bbox=bbox,
    groupby="solar_day",
    measurements=[
        "red",
        "green",
        "blue",
        "nir",
        "nir09",
        "swir16",
        "swir22",
        "coastal",
        "rededge1",
        "rededge2",
        "rededge3",
        "scl"
    ]
)

# 0: No Data, 1: Saturated/Defective, 2: Dark Area Pixel, 3: Cloud Shadows, 4: Vegetation, 5: Bare Soils, 6: Water, 7: Unclassiffied, 8: Medium Probability Clouds, 9: High Probability Clouds, 10: Thin Cirrus, 11: Snow or Ice
mask_flags = [1, 3, 8, 9, 10, 11]
#mask_flags = [0, 1, 3, 8, 9, 10, 11]
cloud_mask = ~data.scl.isin(mask_flags)
masked = data.where(cloud_mask).drop_vars("scl")

# %%
# # data = utils.load_data
# data = load_data(items, bbox)

# %% [markdown]
# <font color='blue'>Set scale and masks and consider the dataset information below including the bands used for analysis:</font>

# %%
scaled = (masked.where(masked != 0) * 0.0001).clip(0, 1)

# %% [markdown]
# <font color='blue'>Explore the satellite image dataset you have loaded</font>

# %%
# time is the number of images over the span of the specified timeframe above (2017 to now)
scaled.isel(time=10).odc.explore(bands=("red", "green", "blue"), vmin=0, vmax=0.3)
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/odc/geo/_rgba.py:55: RuntimeWarning: invalid value encountered in cast
#   return x.astype("uint8")
# /srv/conda/envs/notebook/lib/python3.10/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfa81994cd42e50e6f99e32eb91533ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfa81994cd42e50e6f99e32eb91533ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfa81994cd42e50e6f99e32eb91533ae = L.map(
#                 &quot;map_dfa81994cd42e50e6f99e32eb91533ae&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3a2867d712036c2a032af024218e26b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3a2867d712036c2a032af024218e26b.addTo(map_dfa81994cd42e50e6f99e32eb91533ae);
#
#
#             var image_overlay_664c53c8bca314579bde8ba6a406dfbf = L.imageOverlay(
#                 &quot;...&quot;,
#                 [[-18.254645650201443, 177.82914468867264], [-18.26223813145268, 177.83642104247403]],
#                 {
# }
#             );
#
#
#             image_overlay_664c53c8bca314579bde8ba6a406dfbf.addTo(map_dfa81994cd42e50e6f99e32eb91533ae);
#
#
#             map_dfa81994cd42e50e6f99e32eb91533ae.fitBounds(
#                 [[-18.254757435901706, 177.8292298186452], [-18.262047305055127, 177.83626442535427]],
#                 {}
#             );
#
#
#             var layer_control_4653b10e344ff5597cca80e6a643b7a7_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e3a2867d712036c2a032af024218e26b,
#                 },
#                 overlays :  {
#                     &quot;ro_rgba-70233089e3829748a9576cd76f967e07-3b64992dc03a6e1ae46e2e6787bd514c&quot; : image_overlay_664c53c8bca314579bde8ba6a406dfbf,
#                 },
#             };
#             let layer_control_4653b10e344ff5597cca80e6a643b7a7 = L.control.layers(
#                 layer_control_4653b10e344ff5597cca80e6a643b7a7_layers.base_layers,
#                 layer_control_4653b10e344ff5597cca80e6a643b7a7_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_dfa81994cd42e50e6f99e32eb91533ae);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Mask land

# %%
#### Mask land

mndwi = (scaled["green"]-scaled["swir16"])/(scaled["green"]+scaled["swir16"])
## Moderate land mask
# mndwi_land_mask = mndwi > 0

mndwi_land_mask = mndwi > -0.22

masked_ds = scaled.where(mndwi_land_mask)

masked_ds.isel(time=10).odc.explore(bands=("red", "green", "blue"), vmin=0, vmax=0.3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc8e64fb57882c0d67d14afee40b6459 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc8e64fb57882c0d67d14afee40b6459&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc8e64fb57882c0d67d14afee40b6459 = L.map(
#                 &quot;map_dc8e64fb57882c0d67d14afee40b6459&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffb26f729154d3729d4a17f96d6cae04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ffb26f729154d3729d4a17f96d6cae04.addTo(map_dc8e64fb57882c0d67d14afee40b6459);
#
#
#             var image_overlay_82e1910800ad46834b30c975a01090df = L.imageOverlay(
#                 &quot;...&quot;,
#                 [[-18.254645650201443, 177.82914468867264], [-18.26223813145268, 177.83642104247403]],
#                 {
# }
#             );
#
#
#             image_overlay_82e1910800ad46834b30c975a01090df.addTo(map_dc8e64fb57882c0d67d14afee40b6459);
#
#
#             map_dc8e64fb57882c0d67d14afee40b6459.fitBounds(
#                 [[-18.254757435901706, 177.8292298186452], [-18.262047305055127, 177.83626442535427]],
#                 {}
#             );
#
#
#             var layer_control_1c2bad06de9af500ccbf638545694f1d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ffb26f729154d3729d4a17f96d6cae04,
#                 },
#                 overlays :  {
#                     &quot;ro_rgba-b8b1cff2ebb560b1080d07550d25d690-56091321153af24e6326400b33b5b877&quot; : image_overlay_82e1910800ad46834b30c975a01090df,
#                 },
#             };
#             let layer_control_1c2bad06de9af500ccbf638545694f1d = L.control.layers(
#                 layer_control_1c2bad06de9af500ccbf638545694f1d_layers.base_layers,
#                 layer_control_1c2bad06de9af500ccbf638545694f1d_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_dc8e64fb57882c0d67d14afee40b6459);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ndti = (masked_ds["red"]-masked_ds["green"])/(masked_ds["red"]+masked_ds["green"])

# %%
masked_ds["ndti"] = (masked_ds["red"]-masked_ds["green"])/(masked_ds["red"]+masked_ds["green"])

plt.hist(masked_ds.ndti.to_numpy().flatten(), color = 'blue', edgecolor = 'black',
         bins = 8000)
plt.xlim((-1.0,0.5))

# Add labels
plt.xlabel('NDTI')
plt.ylabel('Count of pixels')
# Out:
# Text(0, 0.5, 'Count of pixels')

# %%
ndti.plot()
# Out:
# (array([1.00000e+00, 7.00000e+00, 2.23970e+04, 1.51344e+05, 2.32987e+05,
#         3.31889e+05, 2.10248e+05, 1.77810e+04, 3.01000e+02, 7.00000e+00]),
#  array([-0.93103445, -0.8070361 , -0.68303776, -0.55903947, -0.43504113,
#         -0.31104279, -0.18704447, -0.06304614,  0.06095219,  0.18495052,
#          0.30894884]),
#  <BarContainer object of 10 artists>)

# %%
ndti.isel(time=10).odc.explore(cmap='BrBG_r', vmin=-0.2, vmax=0.2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60f5100333a7331f7e712e895f5f270b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60f5100333a7331f7e712e895f5f270b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60f5100333a7331f7e712e895f5f270b = L.map(
#                 &quot;map_60f5100333a7331f7e712e895f5f270b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bc602cff8b307d2081fbaaf19d6d40e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bc602cff8b307d2081fbaaf19d6d40e.addTo(map_60f5100333a7331f7e712e895f5f270b);
#
#
#             var image_overlay_72aba01ef46dc6e649603a8160c7ec76 = L.imageOverlay(
#                 &quot;...&quot;,
#                 [[-18.254645650201443, 177.82914468867264], [-18.26223813145268, 177.83642104247403]],
#                 {
# }
#             );
#
#
#             image_overlay_72aba01ef46dc6e649603a8160c7ec76.addTo(map_60f5100333a7331f7e712e895f5f270b);
#
#
#             map_60f5100333a7331f7e712e895f5f270b.fitBounds(
#                 [[-18.254757435901706, 177.8292298186452], [-18.262047305055127, 177.83626442535427]],
#                 {}
#             );
#
#
#             var layer_control_2b58c25ade4fcc73aa4e90afcf229239_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3bc602cff8b307d2081fbaaf19d6d40e,
#                 },
#                 overlays :  {
#                     &quot;macro_element_72aba01ef46dc6e649603a8160c7ec76&quot; : image_overlay_72aba01ef46dc6e649603a8160c7ec76,
#                 },
#             };
#             let layer_control_2b58c25ade4fcc73aa4e90afcf229239 = L.control.layers(
#                 layer_control_2b58c25ade4fcc73aa4e90afcf229239_layers.base_layers,
#                 layer_control_2b58c25ade4fcc73aa4e90afcf229239_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_60f5100333a7331f7e712e895f5f270b);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Compute NDTI over time for each pixel

# %%
# #raw ndti
# raw_ndti = masked_ds['ndti'] (dim='time', skipna=True)

ndti_raw = (masked_ds["red"]-masked_ds["green"])/(masked_ds["red"]+masked_ds["green"])
mean_ndti = masked_ds['ndti'].mean(dim=('x', 'y'), skipna=True)

# %% [markdown]
# Mask (set to NaN or another value) those pixels where this std exceeds your threshold

# %%
plt.figure(figsize=(8, 5))
plt.plot(masked_ds['time'], mean_ndti, marker='o', linestyle='-')
# plt.errorbar(masked_ds['time'], mean_ndti, yerr=std_ndti, fmt='-o', label='Mean ± Std')
plt.xlabel('Date')
plt.ylabel('Mean NDTI')
plt.title('Mean NDTI Over Time')
plt.grid(True)
plt.tight_layout()
plt.gcf().autofmt_xdate()
plt.show()

# %%
threshold = 0.05
thresholds = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8]
mask_ndti = ndti_raw > threshold
masked_ds = masked_ds.where(~mask_ndti)

# %%
plt.imshow(masked_ds['ndti'].isel(time=0), cmap='gray')
plt.title('Masked NDTI overlayed over image 1')
plt.show()

# %%
plt.imshow(masked_ds['ndti'].mean(dim='time'), cmap='gray')
plt.title('Masked NDTI overlayed over mean image')
plt.show()

# %%
ndti
# Out:
# <xarray.DataArray (time: 252, y: 81, x: 74)> Size: 6MB
# dask.array<truediv, shape=(252, 81, 74), dtype=float32, chunksize=(1, 81, 74), chunktype=numpy.ndarray>
# Coordinates:
#   * y            (y) float64 648B 7.981e+06 7.981e+06 ... 7.981e+06 7.981e+06
#   * x            (x) float64 592B 5.877e+05 5.877e+05 ... 5.884e+05 5.884e+05
#     spatial_ref  int32 4B 32760
#   * time         (time) datetime64[ns] 2kB 2017-01-27T22:30:44.463000 ... 202...

# %%
plt.figure(figsize=(8, 5))
plt.plot(masked_ds['time'], mean_ndti, marker='o', linestyle='-')
# plt.errorbar(masked_ds['time'], mean_ndti, yerr=std_ndti, fmt='-o', label='Mean ± Std')
plt.xlabel('Date')
plt.ylabel('Mean NDTI')
plt.title('Mean NDTI Over Time')
plt.grid(True)
plt.tight_layout()
plt.gcf().autofmt_xdate()
plt.show()

# %%
# plt.figure(figsize=(8, 5))
# plt.plot(masked_ds['time'], ndti, marker='o', linestyle='-')
# # plt.errorbar(masked_ds['time'], mean_ndti, yerr=std_ndti, fmt='-o', label='Mean ± Std')
# plt.xlabel('Date')
# plt.ylabel('Mean NDTI')
# plt.title('Mean NDTI Over Time')
# plt.grid(True)
# plt.tight_layout()
# plt.gcf().autofmt_xdate()
# plt.show()

# %%
# n = len(thresholds)

# fig, axes = plt.subplots(nrows=1, ncols=n, figsize=(4*n, 4))

# for i, thresh in enumerate(thresholds):
#     mask = ndti_raw > thresh  # std_ndti is 2D (y, x)
#     ax = axes[i]
#     im = ax.imshow(mask, cmap='gray')
#     ax.set_title(f'Threshold: {thresh}')
#     ax.axis('off')

# plt.tight_layout()
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

threshold_a = 0.25
threshold_b = 0.30

mask_a = mean_ndti > threshold_a  # std_ndti is 2D
mask_b = mean_ndti > threshold_b

# Combine masks: 0 = below both, 1 = above A only, 2 = above both
combined = np.zeros(mean_ndti.shape, dtype=int)
combined[mask_a] = 1
combined[mask_b] = 2

# Custom colormap: 0=white, 1=red, 2=blue (adjust as you wish)
cmap = ListedColormap(['white', 'red', 'blue'])

plt.imshow(combined, cmap=cmap)
plt.title(f'Mask: Red=std>{threshold_a}, Blue=std>{threshold_b}')
plt.axis('off')
plt.show()

# %%
# mean_ndti = masked_ds['ndti'].mean(dim=('x', 'y'), skipna=True)
# median_ndti = masked_ds['ndti'].median(dim=('x', 'y'), skipna=True)
# std_ndti = masked_ds['ndti'].std(dim=('x', 'y'), skipna=True)
# max_ndti = masked_ds['ndti'].max(dim=('x', 'y'), skipna=True)

# %%
# var_ndti = masked_ds['ndti'].var(dim=('x', 'y'), skipna=True)
# quant90_ndti = masked_ds['ndti'].quantile(0.9, dim=('x', 'y'), skipna=True)

# %%
# plt.figure(figsize=(8, 5))
# plt.plot(masked_ds['time'], mean_ndti, marker='o', linestyle='-')
# # plt.errorbar(masked_ds['time'], mean_ndti, yerr=std_ndti, fmt='-o', label='Mean ± Std')
# plt.xlabel('Date')
# plt.ylabel('Mean NDTI')
# plt.title('Mean NDTI Over Time')
# plt.grid(True)
# plt.tight_layout()
# plt.gcf().autofmt_xdate()
# plt.show()

# %%
# plt.figure(figsize=(8, 5))
# plt.plot(masked_ds['time'].values, std_ndti, marker='o', linestyle='-')
# plt.xlabel('Date')
# plt.ylabel('Standard Deviation NDTI')
# plt.title('Standard Deviation NDTI Over Time')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(8, 5))
# plt.plot(masked_ds['time'].values, median_ndti, marker='o', linestyle='-')
# plt.xlabel('Date')
# plt.ylabel('Median NDTI')
# plt.title('Median NDTI Over Time')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(8, 5))
# plt.plot(masked_ds['time'], var_ndti, marker='o', linestyle='-')

# # plt.errorbar(masked_ds['time'], mean_ndti, yerr=std_ndti, fmt='-o', label='Mean ± Std')
# plt.xlabel('Date')
# plt.ylabel('Variance in NDTI')
# plt.title('Variance NDTI Over Time')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(8, 5))
# plt.plot(masked_ds['time'], quant90_ndti, marker='o', linestyle='-')

# # plt.errorbar(masked_ds['time'], mean_ndti, yerr=std_ndti, fmt='-o', label='Mean ± Std')
# plt.xlabel('Date')
# plt.ylabel('0.9 - Quantile in NDTI')
# plt.title('0.9 - Quantile NDTI Over Time')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# time = masked_ds['time'].values  # or use pd.to_datetime(ds['time'].values) if needed

# plt.figure(figsize=(12,6))
# plt.plot(time, mean_ndti, label='Mean NDTI')
# plt.plot(time, max_ndti, label='Max NDTI')
# plt.plot(time, std_ndti, label='Std NDTI')
# plt.plot(time, var_ndti, label='Variance in NDTI')
# plt.plot(time, quant90_ndti, label='90th Percentile NDTI')

# plt.xlabel('Date')
# plt.ylabel('NDTI')
# plt.title('NDTI Statistics Over Time')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# time = masked_ds['time'].values  # or use pd.to_datetime(ds['time'].values) if needed

# plt.figure(figsize=(12,6))
# plt.plot(time, std_ndti, label='Std NDTI')
# plt.plot(time, var_ndti, label='Variance in NDTI')
# plt.plot(time, quant90_ndti, label='90th Percentile NDTI')

# plt.xlabel('Date')
# plt.ylabel('NDTI')
# plt.title('NDTI Statistics Over Time')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# time = masked_ds['time'].values  # or use pd.to_datetime(ds['time'].values) if needed

# plt.figure(figsize=(12,6))
# plt.plot(time, std_ndti, label='Std NDTI')
# plt.plot(time, quant90_ndti, label='90th Percentile NDTI')

# plt.xlabel('Date')
# plt.ylabel('NDTI')
# plt.title('NDTI Statistics Over Time')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# time = masked_ds['time'].values  # or use pd.to_datetime(ds['time'].values) if needed

# plt.figure(figsize=(12,6))
# plt.plot(time, std_ndti, label='Std NDTI')

# plt.xlabel('Date')
# plt.ylabel('NDTI')
# plt.title('NDTI Statistics Over Time')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Compute the standard deviation of NDTI over time for each pixel

# %%
# std_ndti = masked_ds['ndti'].std(dim='time', skipna=True)

# %% [markdown]
# Mask (set to NaN or another value) those pixels where this std exceeds your threshold

# %%
# threshold = 0.05
# thresholds = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8]
# mask_std_ndti = std_ndti > threshold
# masked_ds = masked_ds.where(~mask_std_ndti)

# %%
# plt.imshow(masked_ds['ndti'].isel(time=0), cmap='gray')
# plt.title('Masked NDTI overlayed over image 1')
# plt.show()

# %%
# plt.imshow(masked_ds['ndti'].mean(dim='time'), cmap='gray')
# plt.title('Mean Masked NDTI overlayed over mean image')
# plt.show()

# %%
# n = len(thresholds)

# fig, axes = plt.subplots(nrows=1, ncols=n, figsize=(4*n, 4))

# for i, thresh in enumerate(thresholds):
#     mask = std_ndti > thresh  # std_ndti is 2D (y, x)
#     ax = axes[i]
#     im = ax.imshow(mask, cmap='gray')
#     ax.set_title(f'Threshold: {thresh}')
#     ax.axis('off')

# plt.tight_layout()
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.colors import ListedColormap

# threshold_a = 0.25
# threshold_b = 0.30

# mask_a = std_ndti > threshold_a  # std_ndti is 2D
# mask_b = std_ndti > threshold_b

# # Combine masks: 0 = below both, 1 = above A only, 2 = above both
# combined = np.zeros(std_ndti.shape, dtype=int)
# combined[mask_a] = 1
# combined[mask_b] = 2

# # Custom colormap: 0=white, 1=red, 2=blue (adjust as you wish)
# cmap = ListedColormap(['white', 'red', 'blue'])

# plt.imshow(combined, cmap=cmap)
# plt.title(f'Mask: Red=std>{threshold_a}, Blue=std>{threshold_b}')
# plt.axis('off')
# plt.show()
